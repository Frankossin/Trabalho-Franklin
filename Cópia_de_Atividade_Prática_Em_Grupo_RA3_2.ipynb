# %% [markdown]
# <a href="https://colab.research.google.com/github/Frankossin/Trabalho-Franklin/blob/Modelagem-fisica/C%C3%B3pia_de_Atividade_Pr%C3%A1tica_Em_Grupo_RA3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Questão 1
# 1. **Análise de Sinais Sonoros**
#
#    Um microfone registra um sinal sonoro cuja intensidade $I(t)$ varia com o tempo de acordo com a função $I(t) = 20\sin(t) + 50$. O tempo $t$ está em segundos. Determine a intensidade sonora total registrada pelo microfone em um intervalo de 10 segundos.
#
# 2. **Aceleração de uma Nave Espacial**
#
#    Uma nave espacial está acelerando de acordo com a seguinte função de aceleração: $a(t) = 10\cos(t) + 30$ m/s², onde $t$ é o tempo em segundos. Determine a mudança total na velocidade da nave nos primeiros 5 segundos.
#
# 3. **Cálculo do Consumo de Energia**
#
#    Um servidor de um data center consome energia de acordo com a função $E(t) = 200 + 100\sin(t)$, onde $E$ é a energia em watts e $t$ é o tempo em horas. Calcule o total de energia consumida pelo servidor em 24 horas.
#
# 4. **Volume de Líquido em um Reservatório**
#
#    A taxa de fluxo de água entrando em um reservatório em litros por segundo é dada pela função $f(t) = 100 + 20\sin(t)$, onde $t$ é o tempo em segundos. Calcule o total de água que entrou no reservatório nos primeiros 60 segundos.
#
#
# ## Soluções

# %%
#1
import numpy as np
import matplotlib.pyplot as plt
from sympy import symbols, sin, integrate, lambdify

t = symbols('t')
f_symp = 20 * sin(t) + 50

integral = integrate(f_symp,(t,0,10))
integral_val = float(integral)

print(f"valor da integral definida: {integral_val}")

f = lambdify(t,f_symp,'numpy')

t_val = np.linspace(0,10,1000)
f_val = f(t_val)

plt.figure(figsize=(10,6))
plt.plot(t_val,f_val,label = '$I(t) = 20 * \sin (t) + 50 $')

plt.axvline(x=0, color='blue', linestyle='--')
plt.axvline(x=10, color='blue', linestyle='--')

idx = np.where((t_val >= 0) & (t_val <= 10))
plt.fill_between(t_val[idx], f_val[idx], color='skyblue', alpha=0.3)
plt.xlabel('Tempo (t)')
plt.ylabel('f(t)')
plt.grid(True)
plt.show()
# Out:
# valor da integral definida: 536.7814305815291

# %%
#2
import numpy as np
import matplotlib.pyplot as plt
from sympy import symbols, cos, integrate, lambdify

t = symbols('t')
f_symp = 10 * cos(t) + 30

integral = integrate(f_symp,(t,0,5))
integral_val = float(integral)

print(f"valor da integral definida: {integral_val}")

f = lambdify(t,f_symp,'numpy')

t_val = np.linspace(0,5,1000)
f_val = f(t_val)

plt.figure(figsize=(10,6))
plt.plot(t_val,f_val,label = '$I(t) = 10 * \cos (t) + 30 $')

plt.axvline(x=0, color='blue', linestyle='--')
plt.axvline(x=5, color='blue', linestyle='--')

idx = np.where((t_val >= 0) & (t_val <= 5))
plt.fill_between(t_val[idx], f_val[idx], color='skyblue', alpha=0.3)
plt.xlabel('Tempo (t)')
plt.ylabel('f(t)')
plt.grid(True)
plt.show()
# Out:
# valor da integral definida: 140.41075725336862

# %%
#3
import numpy as np
import matplotlib.pyplot as plt
from sympy import symbols, sin, integrate, lambdify

t = symbols('t')
f_symp = 200 + 100 * sin(t)

integral = integrate(f_symp,(t,0,24))
integral_val = float(integral)

print(f"valor da integral definida: {integral_val}")

f = lambdify(t,f_symp,'numpy')

t_val = np.linspace(-1,25,1000)
f_val = f(t_val)

plt.figure(figsize=(10,6))
plt.plot(t_val,f_val,label = '$I(t) = 200 + 100 * \sin (t)$')

plt.axvline(x=0, color='blue', linestyle='--')
plt.axvline(x=24, color='blue', linestyle='--')

idx = np.where((t_val >= 0) & (t_val <= 24))
plt.fill_between(t_val[idx], f_val[idx], color='skyblue', alpha=0.3)
plt.xlabel('Tempo (t)')
plt.ylabel('f(t)')
plt.grid(True)
plt.show()
# Out:
# valor da integral definida: 4857.5820992663

# %%
#4
import numpy as np
import matplotlib.pyplot as plt
from sympy import symbols, sin, integrate, lambdify

t = symbols('t')
f_symp = 100 + 20 * sin(t)

integral = integrate(f_symp,(t,0,60))
integral_val = float(integral)

print(f"valor da integral definida: {integral_val}")

f = lambdify(t,f_symp,'numpy')

t_val = np.linspace(0,70,1000)
f_val = f(t_val)

plt.figure(figsize=(10,6))
plt.plot(t_val,f_val,label = '$I(t) = 100 + 20  * \sin (t)$')

plt.axvline(x=0, color='blue', linestyle='--')
plt.axvline(x=60, color='blue', linestyle='--')

idx = np.where((t_val >= 0) & (t_val <= 60))
plt.fill_between(t_val[idx], f_val[idx], color='skyblue', alpha=0.3)
plt.xlabel('Tempo (t)')
plt.ylabel('f(t)')
plt.grid(True)
plt.show()
# Out:
# valor da integral definida: 6039.048259608303

# %% [markdown]
# # Questão 2
# Um veículo autônomo está sendo testado em um circuito fechado. Durante o teste, o veículo registra a sua velocidade em cinco momentos distintos, conforme apresentado na tabela abaixo:
#
# | Tempo (s) | Velocidade (m/s) |
# |-----------|------------------|
# | 0         | 0                |
# | 1         | 3                |
# | 2         | 4                |
# | 3         | 2                |
# | 4         | 0                |
#
# Suponha que a função de velocidade $v(t)$ do veículo possa ser representada por um polinômio $P(t)$ que passa por todos os cinco pontos. O método de Lagrange é uma técnica para encontrar esse polinômio, e pode ser aplicado utilizando a biblioteca `scipy` do Python. Trace os gráficos da velocidade, aceleração e posição em relação ao tempo e marque estes três valores com uma linha vertical em $t=5$s.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import lagrange

t = np.array([0,1,2,3,4])
v = np.array([0,3,4,2,0])

#Funcoes para os graficos
poly = lagrange(t,v)
poly_diff = poly.deriv()
poly_integral = poly.integ()

#valores no ponto 5
print(f'Velocidade no ponto 5: {poly(5)}')
print(f'Aceleração no ponto 5: {poly_diff(5)}')
print(f'Deslocamento no ponto 5: {poly_integral(5)}')

#grafico velocidade
x = np.linspace(0,6,1000)
y = poly(x)

plt.figure(figsize=(10,6))
plt.axvline(x=5, color='blue', linestyle='--')
plt.grid(True)
plt.title("Velocidade")
plt.plot(x,y)
plt.show()

#grafico acel
y2 = poly_diff(x)

plt.figure(figsize=(10,6))
plt.axvline(x=5, color='blue', linestyle='--')
plt.grid(True)
plt.title("Aceleração")
plt.plot(x,y2)
plt.show()

#deslocamento
y3 = poly_integral(x)

plt.figure(figsize=(10,6))
plt.axvline(x=5, color='blue', linestyle='--')
plt.grid(True)
plt.title("Deslocamento")
plt.plot(x,y3)
plt.show()
# Out:
# Velocidade no ponto 5: 4.999999999999973
# Aceleração no ponto 5: 11.833333333333323
# Deslocamento no ponto 5: 10.76388888888885

# %% [markdown]
# Um engenheiro está projetando uma barragem de concreto com a forma de um trapézio retângulo. O projeto do perfil da barragem, olhando de lado, é dado pela função $f(x) = a + b\sin\left(\frac{\pi x}{H}\right)$, onde $x$ é a altura acima da base (em metros), $a$ é a altura mínima da barragem (em metros), e $b$ é a amplitude da variação do perfil (em metros). Por razões de segurança, o perfil da barragem varia sinusoidalmente de $a$ até $a + b$ ao longo da altura.
#
# O engenheiro precisa calcular o volume de concreto necessário para construir a barragem. Ele sabe que o comprimento da barragem é de $L$ metros e que o perfil é o mesmo em todo o seu comprimento.
#
# Ele decide então modelar o volume de concreto necessário como a integral da função $f(x)$, de $0$ até a altura máxima $H$, multiplicada pelo comprimento $L$.
#
# Dadas as seguintes informações:
#
# - $a = 10$ metros
# - $b = 5$ metros
# - $H = 20$ metros
# - $L = 100$ metros
#
# Calcule o volume de concreto necessário para a construção da barragem e trace o gráfico da função que descreve o perfil da barragem e sombreie a área sob a curva que representa o volume de concreto.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import symbols, sin, integrate, lambdify, pi

a = 10
b = 5
H = 20
L = 100
x = symbols('x')

f_sy = a + b * sin((pi * x)/H)

integral = integrate(f_sy,(x, 0, H))* L
integral_val = float(integral)
print(f'Volume de concreto necessario: {integral_val}')

f = lambdify(x,f_sy,'numpy')

x_val = np.linspace(0,H,1000)
f_val = f(x_val)

plt.figure(figsize=(10,6))
plt.plot(x_val,f_val)

plt.axvline(x=0, color='blue', linestyle='--')
plt.axvline(x=H, color='blue', linestyle='--')

idx = np.where((x_val >= 0) & (x_val <= H))
plt.fill_between(x_val[idx], f_val[idx], color='skyblue', alpha=0.3)
plt.xlabel('X')
plt.ylabel('f(X)')
plt.grid(True)
plt.show()
# Out:
# Volume de concreto necessario: 26366.197723675814
